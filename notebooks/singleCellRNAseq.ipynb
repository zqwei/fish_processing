# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('glia_neurons_genes.xlsx')

# %% [markdown]
# ### Pool the genes related to voltage-dependent calcium channel

# %%
df_ca = df[df['Annotation'].str.contains("calcium")==True]
df_ca[df_ca['Annotation'].str.contains("voltage")==True]#.to_excel('Calcium_channel_gene.xlsx')
# Out:
#             Gene  Unnamed: 1  Std gene  \
# 1608     cacng6a         NaN    Cacng6
# 5678      cacnb1         NaN    Cacnb1
# 5790     cacnb2a         NaN    Cacnb2
# 5939     cacnb4a         NaN    Cacnb4
# 6011     cacnb3a         NaN    Cacnb3
# 6238     cacnb2b         NaN       NaN
# 7323     cacng2a         NaN    Cacng2
# 7336        hpca         NaN   Cacna1a
# 7435    cacna1da         NaN   Cacna1d
# 7701   cacna2d2a         NaN       NaN
# 8258     cacnb4b         NaN       NaN
# 8490    cacna1ba         NaN   Cacna1b
# 8549    cacna1sa         NaN   Cacna1s
# 8924     cacng8a         NaN       NaN
# 9065     cacna1c         NaN   Cacna1c
# 11171  cacna2d2b         NaN  Cacna2d2
# 11262    cacng7a         NaN    Cacng7
# 11996   cacna1sb         NaN   Cacna1s
# 12346  cacna2d1a         NaN  Cacna2d1
# 14160    cacng1a         NaN    Cacng1
#
#                                               Annotation Unnamed: 4  Glia #  \
# 1608   calcium channel, voltage-dependent, gamma subu...        NaN       0
# 5678   calcium channel, voltage-dependent, beta 1 sub...        NaN    1081
# 5790   calcium channel, voltage-dependent, beta 2 sub...        NaN     967
# 5939   calcium channel, voltage-dependent, beta 4 sub...        NaN    1162
# 6011   calcium channel, voltage-dependent, beta 3 sub...        NaN     213
# 6238           calcium channel voltage-dependent beta 2b        NaN      30
# 7323   calcium channel, voltage-dependent, gamma subu...        NaN     381
# 7336   calcium channel, voltage-dependent, P/Q type, ...        NaN     147
# 7435   calcium channel, voltage-dependent, L type, al...        NaN    3024
# 7701    calcium channel voltage-dependent alpha 2/del...        NaN     476
# 8258    calcium channel voltage-dependent beta 4b sub...        NaN    1747
# 8490   calcium channel, voltage-dependent, N type, al...        NaN    1236
# 8549   calcium channel, voltage-dependent, L type, al...        NaN      46
# 8924    calcium channel voltage-dependent gamma subun...        NaN      81
# 9065   calcium channel, voltage-dependent, L type, al...        NaN     999
# 11171  calcium channel, voltage-dependent, alpha 2/de...        NaN     360
# 11262  calcium channel, voltage-dependent, gamma subu...        NaN      16
# 11996  calcium channel, voltage-dependent, L type, al...        NaN      27
# 12346  calcium channel, voltage-dependent, alpha2/del...        NaN      10
# 14160  calcium channel, voltage-dependent, gamma subu...        NaN       0
#
#        Neuron #  Glia/Neuron  Neuron/Glia
# 1608          0          NaN          NaN
# 5678        294     3.676871     0.271970
# 5790        280     3.453571     0.289555
# 5939        367     3.166213     0.315835
# 6011         70     3.042857     0.328638
# 6238         11     2.727273     0.366667
# 7323        214     1.780374     0.561680
# 7336         83     1.771084     0.564626
# 7435       1766     1.712344     0.583995
# 7701        302     1.576159     0.634454
# 8258       1312     1.331555     0.751002
# 8490       1001     1.234765     0.809871
# 8549         38     1.210526     0.826087
# 8924         75     1.080000     0.925926
# 9065        969     1.030960     0.969970
# 11171       749     0.480641     2.080556
# 11262        35     0.457143     2.187500
# 11996        98     0.275510     3.629630
# 12346        51     0.196078     5.100000
# 14160         2     0.000000          NaN

# %% [markdown]
# ### Pool the genes related to voltage-dependent sodium channel

# %%
df_na = df[df['Annotation'].str.contains("sodium")==True]
df_na[df_na['Annotation'].str.contains("voltage")==True]
# Out:
#           Gene  Unnamed: 1 Std gene  \
# 5521    scn4ab         NaN      NaN
# 5765     scn2b         NaN    Scn2b
# 7024    scn8ab         NaN    Scn8a
# 7341     scn1a         NaN    Scn1a
# 7350    scn1bb         NaN    Scn1b
# 7472    scn4aa         NaN    Scn4a
# 7536   scn12ab         NaN    Scn5a
# 8742   scn1lab         NaN   Scn2a1
# 9851    scn8aa         NaN    Scn8a
# 11594   scn1ba         NaN    Scn1b
# 12224  scn12aa         NaN    Scn5a
# 13154    scn3b         NaN    Scn3b
#
#                                             Annotation Unnamed: 4  Glia #  \
# 5521      sodium channel voltage-gated type IV alpha b        NaN      60
# 5765      sodium channel, voltage-gated, type II, beta        NaN     112
# 7024   sodium channel, voltage-gated, type VIII, alpha        NaN    1906
# 7341      sodium channel, voltage-gated, type I, alpha        NaN     184
# 7350       sodium channel, voltage-gated, type I, beta        NaN     943
# 7472     sodium channel, voltage-gated, type IV, alpha        NaN      83
# 7536      sodium channel, voltage-gated, type V, alpha        NaN     228
# 8742   sodium channel, voltage-gated, type II, alpha 1        NaN    1826
# 9851   sodium channel, voltage-gated, type VIII, alpha        NaN    2788
# 11594      sodium channel, voltage-gated, type I, beta        NaN     143
# 12224     sodium channel, voltage-gated, type V, alpha        NaN       4
# 13154    sodium channel, voltage-gated, type III, beta        NaN       4
#
#        Neuron #  Glia/Neuron  Neuron/Glia
# 5521         15     4.000000     0.250000
# 5765         32     3.500000     0.285714
# 7024        954     1.997904     0.500525
# 7341        104     1.769231     0.565217
# 7350        535     1.762617     0.567338
# 7472         49     1.693878     0.590361
# 7536        137     1.664234     0.600877
# 8742       1592     1.146985     0.871851
# 9851       3446     0.809054     1.236011
# 11594       384     0.372396     2.685315
# 12224        18     0.222222     4.500000
# 13154       535     0.007477   133.750000
