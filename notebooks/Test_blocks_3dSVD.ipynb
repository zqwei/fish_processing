# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale=2)
sns.set_style("white")
# %load_ext autoreload
# %autoreload 2
import os, sys
fish_path = os.path.abspath(os.path.join('..'))
if fish_path not in sys.path:
    sys.path.append(fish_path)
from utils.memory import get_process_memory, clear_variables

# %%
from denoiseLocalPCA.denoise import tool_grid

# %%
dims = (320, 364, 9000)
nblocks = (30, 30)
row_array,col_array = tool_grid.tile_grids(dims,nblocks)

# %%
dat_ = np.random.randn(320, 364, 9000)

# %%
W_ = tool_grid.split_image_into_blocks(dat_,nblocks=nblocks)

# %%
dims_ = list(map(np.shape,W_))

# %%
tool_grid.pyramid_tiles(dims,dims_,list_order='C',plot_en=True)
# Out:
# array([[0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ],
#        [0.  , 0.2 , 0.2 , ..., 0.2 , 0.2 , 0.  ],
#        [0.  , 0.2 , 0.4 , ..., 0.4 , 0.2 , 0.  ],
#        ...,
#        [0.  , 0.25, 0.5 , ..., 0.5 , 0.25, 0.  ],
#        [0.  , 0.25, 0.25, ..., 0.25, 0.25, 0.  ],
#        [0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ]])
