# %%
# load data
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
imgStack = io.imread('/Volumes/ahrenslab/Takashi/toZiqiang/10192017Fish3-1/raw.tif')
plt.imshow(imgStack[0], cmap='gray')
exImg = imgStack[0]

# %%
from simpleDenioseTool import simpleDN
imgD_ = simpleDN(exImg, pixel_x=(772,1280), pixel_y=(832,1120))

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(exImg)
ax1.set_title('Raw image')
ax2.imshow(imgD_)
ax2.set_title('Preprocessed')
f.savefig('comparison.png', dpi=1000)
plt.show()
